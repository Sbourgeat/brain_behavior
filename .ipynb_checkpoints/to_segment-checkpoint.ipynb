# %%
import pandas as pd

# %%
behav = pd.read_csv("/Users/skumar/Documents/PhD/BrainAnalysis/Behavior/summary.csv")
behav
# Out:
#       id genotype     sex       exp_type shock_color shock_arm treatment  \
# 0     17  dgrp100  female  operant_place       green         M   noShock
# 1     18  dgrp100  female  operant_place       green         R   noShock
# 2     19  dgrp100  female  operant_place       green         L   noShock
# 3     20  dgrp100  female  operant_place       green         M   noShock
# 4     21  dgrp100  female  operant_place       green         R   noShock
# ...   ..      ...     ...            ...         ...       ...       ...
# 5307  44     dnc1    male  operant_color        blue       NaN     shock
# 5308  45     dnc1    male  operant_color        blue       NaN     shock
# 5309  46     dnc1    male  operant_color        blue       NaN     shock
# 5310  47     dnc1    male  operant_color        blue       NaN     shock
# 5311  48     dnc1    male  operant_color        blue       NaN     shock
#
#       replicates       ZT0        ZT  ...  post_incorrect_choices  \
# 0              1  11:00:00       NaN  ...                     NaN
# 1              1  11:00:00       NaN  ...                     NaN
# 2              1  11:00:00       NaN  ...                     NaN
# 3              1  11:00:00       NaN  ...                     NaN
# 4              1  11:00:00       NaN  ...                     NaN
# ...          ...       ...       ...  ...                     ...
# 5307           2  11:00:00  18:21:41  ...                    27.0
# 5308           2  11:00:00  18:21:41  ...                    70.0
# 5309           2  11:00:00  18:21:41  ...                    45.0
# 5310           2  11:00:00  18:21:41  ...                    49.0
# 5311           2  11:00:00  18:21:41  ...                    10.0
#
#       post_analysis_time            group               group_sex  \
# 0                    NaN  dgrp100_noShock  dgrp100_noShock_female
# 1                    NaN  dgrp100_noShock  dgrp100_noShock_female
# 2                    NaN  dgrp100_noShock  dgrp100_noShock_female
# 3                    NaN  dgrp100_noShock  dgrp100_noShock_female
# 4                    NaN  dgrp100_noShock  dgrp100_noShock_female
# ...                  ...              ...                     ...
# 5307               600.0       dnc1_shock         dnc1_shock_male
# 5308               600.0       dnc1_shock         dnc1_shock_male
# 5309               600.0       dnc1_shock         dnc1_shock_male
# 5310               600.0       dnc1_shock         dnc1_shock_male
# 5311               600.0       dnc1_shock         dnc1_shock_male
#
#                                                  folder  experiment_date  \
# 0     operant_place/20221222/csv/dgrp100_noShock/female         20221222
# 1     operant_place/20221222/csv/dgrp100_noShock/female         20221222
# 2     operant_place/20221222/csv/dgrp100_noShock/female         20221222
# 3     operant_place/20221222/csv/dgrp100_noShock/female         20221222
# 4     operant_place/20221222/csv/dgrp100_noShock/female         20221222
# ...                                                 ...              ...
# 5307         operant_color/20230806/csv/dnc1_shock/male         20230806
# 5308         operant_color/20230806/csv/dnc1_shock/male         20230806
# 5309         operant_color/20230806/csv/dnc1_shock/male         20230806
# 5310         operant_color/20230806/csv/dnc1_shock/male         20230806
# 5311         operant_color/20230806/csv/dnc1_shock/male         20230806
#
#       experiment_by  head_scanned   abs_dev  abs_dev_sex
# 0            riddha         False  0.159876     0.172520
# 1            riddha         False  0.030237     0.042881
# 2            riddha         False  0.239896     0.227253
# 3            riddha         False  0.025809     0.013166
# 4            riddha         False  0.094741     0.107385
# ...             ...           ...       ...          ...
# 5307         riddha         False  0.099280     0.087237
# 5308         riddha         False  0.082689     0.070646
# 5309         riddha         False  0.082759     0.070715
# 5310         riddha         False  0.164981     0.152937
# 5311         riddha         False  0.074083     0.062040
#
# [5312 rows x 48 columns]

# %%
brain = pd.read_csv("/Users/skumar/Documents/PhD/BrainAnalysis/Results_Vol_Entropy/GWAS_Normalized_EntropyVol.tsv", sep="\t")
brain
# Out:
#          DGRP sex    Volume  Entropy0  Entropy1  Entropy2
# 0    DGRP_228   F  0.010634  1.742000  1.856059  1.821565
# 1    DGRP_228   M  0.010962  1.789805  1.835055  2.143064
# 2    DGRP_332   M  0.012916  1.414558  1.402126  1.227755
# 3    DGRP_100   M  0.014155  1.926577  1.925772  2.231003
# 4    DGRP_332   F  0.015221  1.505315  1.391551  1.341379
# ..        ...  ..       ...       ...       ...       ...
# 96   DGRP_359   F  0.028636  1.606484  1.620327  1.595721
# 97   DGRP_091   F  0.029890  1.716160  1.765672  1.744629
# 98   DGRP_176   F  0.031885  1.664873  1.721217  1.698591
# 99   DGRP_790   M  0.031894  1.638082  1.632863  1.792953
# 100  DGRP_850   F  0.033936  1.648352  1.698413  1.837693
#
# [101 rows x 6 columns]

# %%
def split_string_with_dgrp(df):
    DGRP=[]
    sex = []
    for i in range(len(df)):
        if 'dgrp' in df.iloc[i, 1]:
            #print(df.iloc[i, 1])
            #DGRP.append(df.iloc[i, 1].split('dgrp')[1])
            DGRP.append(df.iloc[i, 1])
            s= df.iloc[i,2]
            #if s == "male" : s="M"
            #else: s="F"
            sex.append(s)
    return DGRP,sex
DGRP,sex = split_string_with_dgrp(behav)

# %%
data = behav[behav['genotype'].isin(DGRP) & behav['sex'].isin(sex) & behav["head_scanned"]==True]

# %%
data
# Out:
#       id genotype     sex       exp_type shock_color shock_arm treatment  \
# 2528   1  dgrp153  female  operant_place       green         L     shock
# 2544   9  dgrp153    male  operant_place       green         R     shock
# 2592   1  dgrp313  female  operant_place       green         L     shock
# 2608   9  dgrp313    male  operant_place       green         R     shock
# 2656   1  dgrp721  female  operant_place       green         L     shock
# ...   ..      ...     ...            ...         ...       ...       ...
# 5049  42  dgrp818    male  operant_place       green         R     shock
# 5097  34  dgrp853  female  operant_place       green         L     shock
# 5113  42  dgrp853    male  operant_place       green         R     shock
# 5161  34  dgrp913  female  operant_place       green         L     shock
# 5177  42  dgrp913    male  operant_place       green         R     shock
#
#       replicates       ZT0        ZT  ...  post_incorrect_choices  \
# 2528           1  16:00:00  17:42:50  ...                     NaN
# 2544           1  16:00:00  17:42:50  ...                     NaN
# 2592           1  11:00:00  13:00:22  ...                     NaN
# 2608           1  11:00:00  13:00:22  ...                     NaN
# 2656           1  11:00:00  14:09:47  ...                     NaN
# ...          ...       ...       ...  ...                     ...
# 5049           2  16:00:00  17:28:50  ...                     NaN
# 5097           2  16:00:00  18:33:26  ...                     NaN
# 5113           2  16:00:00  18:33:26  ...                     NaN
# 5161           2  11:00:00  13:16:11  ...                     NaN
# 5177           2  11:00:00  13:16:11  ...                     NaN
#
#       post_analysis_time          group             group_sex  \
# 2528                 NaN  dgrp153_shock  dgrp153_shock_female
# 2544                 NaN  dgrp153_shock    dgrp153_shock_male
# 2592                 NaN  dgrp313_shock  dgrp313_shock_female
# 2608                 NaN  dgrp313_shock    dgrp313_shock_male
# 2656                 NaN  dgrp721_shock  dgrp721_shock_female
# ...                  ...            ...                   ...
# 5049                 NaN  dgrp818_shock    dgrp818_shock_male
# 5097                 NaN  dgrp853_shock  dgrp853_shock_female
# 5113                 NaN  dgrp853_shock    dgrp853_shock_male
# 5161                 NaN  dgrp913_shock  dgrp913_shock_female
# 5177                 NaN  dgrp913_shock    dgrp913_shock_male
#
#                                                folder  experiment_date  \
# 2528  operant_place/20230414/csv/dgrp153_shock/female         20230414
# 2544    operant_place/20230414/csv/dgrp153_shock/male         20230414
# 2592  operant_place/20230414/csv/dgrp313_shock/female         20230414
# 2608    operant_place/20230414/csv/dgrp313_shock/male         20230414
# 2656  operant_place/20230414/csv/dgrp721_shock/female         20230414
# ...                                               ...              ...
# 5049    operant_place/20230710/csv/dgrp818_shock/male         20230710
# 5097  operant_place/20230710/csv/dgrp853_shock/female         20230710
# 5113    operant_place/20230710/csv/dgrp853_shock/male         20230710
# 5161  operant_place/20230710/csv/dgrp913_shock/female         20230710
# 5177    operant_place/20230710/csv/dgrp913_shock/male         20230710
#
#       experiment_by  head_scanned   abs_dev  abs_dev_sex
# 2528         riddha          True  0.168387     0.130132
# 2544         riddha          True  0.047087     0.008831
# 2592         riddha          True  0.235604     0.245171
# 2608         riddha          True  0.103920     0.113488
# 2656         riddha          True  0.236740     0.205605
# ...             ...           ...       ...          ...
# 5049         riddha          True  0.088770     0.061299
# 5097         riddha          True  0.221883     0.235297
# 5113         riddha          True  0.173586     0.160172
# 5161         riddha          True  0.184951     0.162527
# 5177         riddha          True  0.147875     0.125452
#
# [84 rows x 48 columns]

# %%
#data['genotype'] = "DGRP_"+data['genotype'].str.split('dgrp').str.get(1)

data['genotype'] = data['genotype'].apply(lambda x: 'DGRP_0' + x.split('dgrp')[1] if len(x.split('dgrp')[1]) == 2 else 'DGRP_' + x.split('dgrp')[1])
# Out:
# /var/folders/jc/23tmvmc554b_hqpgl1mn9wch0000gq/T/ipykernel_6976/3671791993.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data
# Out:
#       id  genotype     sex       exp_type shock_color shock_arm treatment  \
# 2528   1  DGRP_153  female  operant_place       green         L     shock
# 2544   9  DGRP_153    male  operant_place       green         R     shock
# 2592   1  DGRP_313  female  operant_place       green         L     shock
# 2608   9  DGRP_313    male  operant_place       green         R     shock
# 2656   1  DGRP_721  female  operant_place       green         L     shock
# ...   ..       ...     ...            ...         ...       ...       ...
# 5049  42  DGRP_818    male  operant_place       green         R     shock
# 5097  34  DGRP_853  female  operant_place       green         L     shock
# 5113  42  DGRP_853    male  operant_place       green         R     shock
# 5161  34  DGRP_913  female  operant_place       green         L     shock
# 5177  42  DGRP_913    male  operant_place       green         R     shock
#
#       replicates       ZT0        ZT  ...  post_incorrect_choices  \
# 2528           1  16:00:00  17:42:50  ...                     NaN
# 2544           1  16:00:00  17:42:50  ...                     NaN
# 2592           1  11:00:00  13:00:22  ...                     NaN
# 2608           1  11:00:00  13:00:22  ...                     NaN
# 2656           1  11:00:00  14:09:47  ...                     NaN
# ...          ...       ...       ...  ...                     ...
# 5049           2  16:00:00  17:28:50  ...                     NaN
# 5097           2  16:00:00  18:33:26  ...                     NaN
# 5113           2  16:00:00  18:33:26  ...                     NaN
# 5161           2  11:00:00  13:16:11  ...                     NaN
# 5177           2  11:00:00  13:16:11  ...                     NaN
#
#       post_analysis_time          group             group_sex  \
# 2528                 NaN  dgrp153_shock  dgrp153_shock_female
# 2544                 NaN  dgrp153_shock    dgrp153_shock_male
# 2592                 NaN  dgrp313_shock  dgrp313_shock_female
# 2608                 NaN  dgrp313_shock    dgrp313_shock_male
# 2656                 NaN  dgrp721_shock  dgrp721_shock_female
# ...                  ...            ...                   ...
# 5049                 NaN  dgrp818_shock    dgrp818_shock_male
# 5097                 NaN  dgrp853_shock  dgrp853_shock_female
# 5113                 NaN  dgrp853_shock    dgrp853_shock_male
# 5161                 NaN  dgrp913_shock  dgrp913_shock_female
# 5177                 NaN  dgrp913_shock    dgrp913_shock_male
#
#                                                folder  experiment_date  \
# 2528  operant_place/20230414/csv/dgrp153_shock/female         20230414
# 2544    operant_place/20230414/csv/dgrp153_shock/male         20230414
# 2592  operant_place/20230414/csv/dgrp313_shock/female         20230414
# 2608    operant_place/20230414/csv/dgrp313_shock/male         20230414
# 2656  operant_place/20230414/csv/dgrp721_shock/female         20230414
# ...                                               ...              ...
# 5049    operant_place/20230710/csv/dgrp818_shock/male         20230710
# 5097  operant_place/20230710/csv/dgrp853_shock/female         20230710
# 5113    operant_place/20230710/csv/dgrp853_shock/male         20230710
# 5161  operant_place/20230710/csv/dgrp913_shock/female         20230710
# 5177    operant_place/20230710/csv/dgrp913_shock/male         20230710
#
#       experiment_by  head_scanned   abs_dev  abs_dev_sex
# 2528         riddha          True  0.168387     0.130132
# 2544         riddha          True  0.047087     0.008831
# 2592         riddha          True  0.235604     0.245171
# 2608         riddha          True  0.103920     0.113488
# 2656         riddha          True  0.236740     0.205605
# ...             ...           ...       ...          ...
# 5049         riddha          True  0.088770     0.061299
# 5097         riddha          True  0.221883     0.235297
# 5113         riddha          True  0.173586     0.160172
# 5161         riddha          True  0.184951     0.162527
# 5177         riddha          True  0.147875     0.125452
#
# [84 rows x 48 columns]

# %%
data.rename(columns={'genotype': 'DGRP'}, inplace=True)
# Out:
# /var/folders/jc/23tmvmc554b_hqpgl1mn9wch0000gq/T/ipykernel_6976/3106402434.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data["sex"] = data["sex"].replace(["male", "female"], ["M", "F"])
# Out:
# /var/folders/jc/23tmvmc554b_hqpgl1mn9wch0000gq/T/ipykernel_6976/264158564.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df = pd.merge(brain, data, on=['DGRP', 'sex'])

# %%
mask = merged_df['DGRP'] != merged_df['DGRP']

# %%
result_df = merged_df[mask]

# %%
data
# Out:
#       id      DGRP sex       exp_type shock_color shock_arm treatment  \
# 2528   1  DGRP_153   F  operant_place       green         L     shock
# 2544   9  DGRP_153   M  operant_place       green         R     shock
# 2592   1  DGRP_313   F  operant_place       green         L     shock
# 2608   9  DGRP_313   M  operant_place       green         R     shock
# 2656   1  DGRP_721   F  operant_place       green         L     shock
# ...   ..       ...  ..            ...         ...       ...       ...
# 5049  42  DGRP_818   M  operant_place       green         R     shock
# 5097  34  DGRP_853   F  operant_place       green         L     shock
# 5113  42  DGRP_853   M  operant_place       green         R     shock
# 5161  34  DGRP_913   F  operant_place       green         L     shock
# 5177  42  DGRP_913   M  operant_place       green         R     shock
#
#       replicates       ZT0        ZT  ...  post_incorrect_choices  \
# 2528           1  16:00:00  17:42:50  ...                     NaN
# 2544           1  16:00:00  17:42:50  ...                     NaN
# 2592           1  11:00:00  13:00:22  ...                     NaN
# 2608           1  11:00:00  13:00:22  ...                     NaN
# 2656           1  11:00:00  14:09:47  ...                     NaN
# ...          ...       ...       ...  ...                     ...
# 5049           2  16:00:00  17:28:50  ...                     NaN
# 5097           2  16:00:00  18:33:26  ...                     NaN
# 5113           2  16:00:00  18:33:26  ...                     NaN
# 5161           2  11:00:00  13:16:11  ...                     NaN
# 5177           2  11:00:00  13:16:11  ...                     NaN
#
#       post_analysis_time          group             group_sex  \
# 2528                 NaN  dgrp153_shock  dgrp153_shock_female
# 2544                 NaN  dgrp153_shock    dgrp153_shock_male
# 2592                 NaN  dgrp313_shock  dgrp313_shock_female
# 2608                 NaN  dgrp313_shock    dgrp313_shock_male
# 2656                 NaN  dgrp721_shock  dgrp721_shock_female
# ...                  ...            ...                   ...
# 5049                 NaN  dgrp818_shock    dgrp818_shock_male
# 5097                 NaN  dgrp853_shock  dgrp853_shock_female
# 5113                 NaN  dgrp853_shock    dgrp853_shock_male
# 5161                 NaN  dgrp913_shock  dgrp913_shock_female
# 5177                 NaN  dgrp913_shock    dgrp913_shock_male
#
#                                                folder  experiment_date  \
# 2528  operant_place/20230414/csv/dgrp153_shock/female         20230414
# 2544    operant_place/20230414/csv/dgrp153_shock/male         20230414
# 2592  operant_place/20230414/csv/dgrp313_shock/female         20230414
# 2608    operant_place/20230414/csv/dgrp313_shock/male         20230414
# 2656  operant_place/20230414/csv/dgrp721_shock/female         20230414
# ...                                               ...              ...
# 5049    operant_place/20230710/csv/dgrp818_shock/male         20230710
# 5097  operant_place/20230710/csv/dgrp853_shock/female         20230710
# 5113    operant_place/20230710/csv/dgrp853_shock/male         20230710
# 5161  operant_place/20230710/csv/dgrp913_shock/female         20230710
# 5177    operant_place/20230710/csv/dgrp913_shock/male         20230710
#
#       experiment_by  head_scanned   abs_dev  abs_dev_sex
# 2528         riddha          True  0.168387     0.130132
# 2544         riddha          True  0.047087     0.008831
# 2592         riddha          True  0.235604     0.245171
# 2608         riddha          True  0.103920     0.113488
# 2656         riddha          True  0.236740     0.205605
# ...             ...           ...       ...          ...
# 5049         riddha          True  0.088770     0.061299
# 5097         riddha          True  0.221883     0.235297
# 5113         riddha          True  0.173586     0.160172
# 5161         riddha          True  0.184951     0.162527
# 5177         riddha          True  0.147875     0.125452
#
# [84 rows x 48 columns]

# %%
import pandas as pd

# Assuming you have two dataframes: df1 and df2

# Merge the dataframes on "DGRP" and "sex"
merged_df = pd.merge(brain, data, on=["DGRP","sex"], how="outer", suffixes=("_df1", "_df2"))

# %%
merged_df
# Out:
#          DGRP sex    Volume  Entropy0  Entropy1  Entropy2    id  \
# 0    DGRP_228   F  0.010634  1.742000  1.856059  1.821565   NaN
# 1    DGRP_228   M  0.010962  1.789805  1.835055  2.143064   NaN
# 2    DGRP_332   M  0.012916  1.414558  1.402126  1.227755   NaN
# 3    DGRP_100   M  0.014155  1.926577  1.925772  2.231003   NaN
# 4    DGRP_332   F  0.015221  1.505315  1.391551  1.341379   NaN
# ..        ...  ..       ...       ...       ...       ...   ...
# 158  DGRP_405   M       NaN       NaN       NaN       NaN   9.0
# 159  DGRP_818   F       NaN       NaN       NaN       NaN  34.0
# 160  DGRP_818   M       NaN       NaN       NaN       NaN  42.0
# 161  DGRP_913   F       NaN       NaN       NaN       NaN  34.0
# 162  DGRP_913   M       NaN       NaN       NaN       NaN  42.0
#
#           exp_type shock_color shock_arm  ... post_incorrect_choices  \
# 0              NaN         NaN       NaN  ...                    NaN
# 1              NaN         NaN       NaN  ...                    NaN
# 2              NaN         NaN       NaN  ...                    NaN
# 3              NaN         NaN       NaN  ...                    NaN
# 4              NaN         NaN       NaN  ...                    NaN
# ..             ...         ...       ...  ...                    ...
# 158  operant_place        blue         R  ...                    NaN
# 159  operant_place       green         L  ...                    NaN
# 160  operant_place       green         R  ...                    NaN
# 161  operant_place       green         L  ...                    NaN
# 162  operant_place       green         R  ...                    NaN
#
#      post_analysis_time          group             group_sex  \
# 0                   NaN            NaN                   NaN
# 1                   NaN            NaN                   NaN
# 2                   NaN            NaN                   NaN
# 3                   NaN            NaN                   NaN
# 4                   NaN            NaN                   NaN
# ..                  ...            ...                   ...
# 158                 NaN  dgrp405_shock    dgrp405_shock_male
# 159                 NaN  dgrp818_shock  dgrp818_shock_female
# 160                 NaN  dgrp818_shock    dgrp818_shock_male
# 161                 NaN  dgrp913_shock  dgrp913_shock_female
# 162                 NaN  dgrp913_shock    dgrp913_shock_male
#
#                                               folder  experiment_date  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# ..                                               ...              ...
# 158    operant_place/20230703/csv/dgrp405_shock/male       20230703.0
# 159  operant_place/20230710/csv/dgrp818_shock/female       20230710.0
# 160    operant_place/20230710/csv/dgrp818_shock/male       20230710.0
# 161  operant_place/20230710/csv/dgrp913_shock/female       20230710.0
# 162    operant_place/20230710/csv/dgrp913_shock/male       20230710.0
#
#      experiment_by  head_scanned   abs_dev  abs_dev_sex
# 0              NaN           NaN       NaN          NaN
# 1              NaN           NaN       NaN          NaN
# 2              NaN           NaN       NaN          NaN
# 3              NaN           NaN       NaN          NaN
# 4              NaN           NaN       NaN          NaN
# ..             ...           ...       ...          ...
# 158         riddha          True  0.164897     0.171137
# 159         riddha          True  0.186570     0.159100
# 160         riddha          True  0.088770     0.061299
# 161         riddha          True  0.184951     0.162527
# 162         riddha          True  0.147875     0.125452
#
# [163 rows x 52 columns]

# %%
# Filter the rows where the values in "DGRP" are not the same
filtered_df = merged_df[merged_df["DGRP_df1"] != merged_df["DGRP_df2"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/brain_analysis/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DGRP_df1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Filter the rows where the values in "DGRP" are not the same
# ----> 2 filtered_df = merged_df[merged_df["DGRP_df1"] != merged_df["DGRP_df2"]]
#
# File ~/opt/anaconda3/envs/brain_analysis/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/brain_analysis/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'DGRP_df1'

# %%
# Print the values in column "DGRP" for the mismatched combinations
mismatched_values = filtered_df["DGRP_df1"].dropna().unique()
print("Mismatched values in column 'DGRP' for the combination of 'DGRP' and 'sex':")
print(mismatched_values)
# Out:
#         DGRP sex_x    Volume  Entropy0  Entropy1  Entropy2  id sex_y  \
# 1   DGRP_732     F  0.015346  1.588548  1.597554  1.260962  48     M
# 2   DGRP_732     M  0.016771  1.783274  1.885432  1.737984  40     F
# 5   DGRP_737     F  0.015415  1.872372  1.885794  2.107636  10     M
# 6   DGRP_737     M  0.018805  1.808627  1.864490  2.106834   2     F
# 9   DGRP_309     F  0.017028  1.472865  1.705017  1.962350   9     M
# 10  DGRP_309     M  0.017826  1.736349  1.755159  1.873762   1     F
# 12  DGRP_437     M  0.017706  1.640324  1.689384  1.834623   2     F
# 15  DGRP_437     F  0.019896  1.616853  1.677944  1.791408  10     M
# 17  DGRP_354     F  0.018734  1.496644  1.578005  1.880820  48     M
# 18  DGRP_354     M  0.019798  1.465704  1.632769  1.955570  40     F
# 21  DGRP_786     F  0.018789  1.650172  1.683090  1.689623  10     M
# 22  DGRP_786     M  0.021380  1.658725  1.704068  1.609534   2     F
# 24  DGRP_031     M  0.019653  1.560371  1.559431  1.639554  40     F
# 26  DGRP_853     M  0.019990  1.646468  1.791665  2.156338  34     F
# 29  DGRP_853     F  0.023340  1.703184  1.724505  2.223834  42     M
# 30  DGRP_091     M  0.020577  1.719971  1.633808  1.545181  40     F
# 33  DGRP_091     F  0.029890  1.716160  1.765672  1.744629  48     M
# 34  DGRP_850     M  0.021624  1.833879  1.853082  2.141067   1     F
# 37  DGRP_850     F  0.033936  1.648352  1.698413  1.837693   9     M
# 39  DGRP_405     F  0.022453  1.675530  1.729582  2.025458   9     M
# 40  DGRP_026     M  0.023203  1.754024  1.748252  1.428661   2     F
# 43  DGRP_026     F  0.025922  1.721604  1.713125  1.712864  10     M
#
#          exp_type shock_color  ... post_incorrect_choices post_analysis_time  \
# 1   operant_place        blue  ...                    NaN                NaN
# 2   operant_place        blue  ...                    NaN                NaN
# 5   operant_place        blue  ...                    NaN                NaN
# 6   operant_place        blue  ...                    NaN                NaN
# 9   operant_place        blue  ...                    NaN                NaN
# 10  operant_place        blue  ...                    NaN                NaN
# 12  operant_place        blue  ...                    NaN                NaN
# 15  operant_place        blue  ...                    NaN                NaN
# 17  operant_place       green  ...                    NaN                NaN
# 18  operant_place       green  ...                    NaN                NaN
# 21  operant_place        blue  ...                    NaN                NaN
# 22  operant_place        blue  ...                    NaN                NaN
# 24  operant_place       green  ...                    NaN                NaN
# 26  operant_place       green  ...                    NaN                NaN
# 29  operant_place       green  ...                    NaN                NaN
# 30  operant_place        blue  ...                    NaN                NaN
# 33  operant_place        blue  ...                    NaN                NaN
# 34  operant_place       green  ...                    NaN                NaN
# 37  operant_place       green  ...                    NaN                NaN
# 39  operant_place        blue  ...                    NaN                NaN
# 40  operant_place        blue  ...                    NaN                NaN
# 43  operant_place        blue  ...                    NaN                NaN
#
#             group             group_sex  \
# 1   dgrp732_shock    dgrp732_shock_male
# 2   dgrp732_shock  dgrp732_shock_female
# 5   dgrp737_shock    dgrp737_shock_male
# 6   dgrp737_shock  dgrp737_shock_female
# 9   dgrp309_shock    dgrp309_shock_male
# 10  dgrp309_shock  dgrp309_shock_female
# 12  dgrp437_shock  dgrp437_shock_female
# 15  dgrp437_shock    dgrp437_shock_male
# 17  dgrp354_shock    dgrp354_shock_male
# 18  dgrp354_shock  dgrp354_shock_female
# 21  dgrp786_shock    dgrp786_shock_male
# 22  dgrp786_shock  dgrp786_shock_female
# 24   dgrp31_shock   dgrp31_shock_female
# 26  dgrp853_shock  dgrp853_shock_female
# 29  dgrp853_shock    dgrp853_shock_male
# 30   dgrp91_shock   dgrp91_shock_female
# 33   dgrp91_shock     dgrp91_shock_male
# 34  dgrp850_shock  dgrp850_shock_female
# 37  dgrp850_shock    dgrp850_shock_male
# 39  dgrp405_shock    dgrp405_shock_male
# 40   dgrp26_shock   dgrp26_shock_female
# 43   dgrp26_shock     dgrp26_shock_male
#
#                                              folder  experiment_date  \
# 1     operant_place/20230621/csv/dgrp732_shock/male         20230621
# 2   operant_place/20230621/csv/dgrp732_shock/female         20230621
# 5     operant_place/20230707/csv/dgrp737_shock/male         20230707
# 6   operant_place/20230707/csv/dgrp737_shock/female         20230707
# 9     operant_place/20230703/csv/dgrp309_shock/male         20230703
# 10  operant_place/20230703/csv/dgrp309_shock/female         20230703
# 12  operant_place/20230705/csv/dgrp437_shock/female         20230705
# 15    operant_place/20230705/csv/dgrp437_shock/male         20230705
# 17    operant_place/20230621/csv/dgrp354_shock/male         20230621
# 18  operant_place/20230621/csv/dgrp354_shock/female         20230621
# 21    operant_place/20230705/csv/dgrp786_shock/male         20230705
# 22  operant_place/20230705/csv/dgrp786_shock/female         20230705
# 24   operant_place/20230621/csv/dgrp31_shock/female         20230621
# 26  operant_place/20230710/csv/dgrp853_shock/female         20230710
# 29    operant_place/20230710/csv/dgrp853_shock/male         20230710
# 30   operant_place/20230621/csv/dgrp91_shock/female         20230621
# 33     operant_place/20230621/csv/dgrp91_shock/male         20230621
# 34  operant_place/20230703/csv/dgrp850_shock/female         20230703
# 37    operant_place/20230703/csv/dgrp850_shock/male         20230703
# 39    operant_place/20230703/csv/dgrp405_shock/male         20230703
# 40   operant_place/20230707/csv/dgrp26_shock/female         20230707
# 43     operant_place/20230707/csv/dgrp26_shock/male         20230707
#
#     experiment_by  head_scanned   abs_dev  abs_dev_sex
# 1          riddha          True  0.140436     0.137686
# 2          riddha          True  0.164331     0.167038
# 5          riddha          True  0.080066     0.069080
# 6          riddha          True  0.207584     0.196769
# 9          riddha          True  0.110822     0.106943
# 10         riddha          True  0.053567     0.057445
# 12         riddha          True  0.157227     0.158835
# 15         riddha          True  0.042431     0.040824
# 17         riddha          True  0.094630     0.113490
# 18         riddha          True  0.017099     0.002430
# 21         riddha          True  0.228288     0.222473
# 22         riddha          True  0.148576     0.154391
# 24         riddha          True  0.068335     0.072473
# 26         riddha          True  0.221883     0.235297
# 29         riddha          True  0.173586     0.160172
# 30         riddha          True  0.124777     0.123178
# 33         riddha          True  0.008511     0.010111
# 34         riddha          True  0.115575     0.118200
# 37         riddha          True  0.072065     0.069440
# 39         riddha          True  0.164897     0.171137
# 40         riddha          True  0.070751     0.077445
# 43         riddha          True  0.202045     0.208740
#
# [22 rows x 53 columns]

# %%
unique_dgrp = data[~data['DGRP'].isin(brain['DGRP'])]

unique_dgrp[["DGRP","sex"]].values
# Out:
# array([['DGRP_153', 'F'],
#        ['DGRP_153', 'M'],
#        ['DGRP_313', 'F'],
#        ['DGRP_313', 'M'],
#        ['DGRP_721', 'F'],
#        ['DGRP_721', 'M'],
#        ['DGRP_808', 'F'],
#        ['DGRP_808', 'M'],
#        ['DGRP_765', 'F'],
#        ['DGRP_765', 'M'],
#        ['DGRP_776', 'F'],
#        ['DGRP_776', 'M'],
#        ['DGRP_855', 'F'],
#        ['DGRP_855', 'M'],
#        ['DGRP_382', 'F'],
#        ['DGRP_382', 'M'],
#        ['DGRP_627', 'F'],
#        ['DGRP_627', 'M'],
#        ['DGRP_440', 'F'],
#        ['DGRP_440', 'M'],
#        ['DGRP_563', 'F'],
#        ['DGRP_563', 'M'],
#        ['DGRP_911', 'F'],
#        ['DGRP_911', 'M'],
#        ['DGRP_227', 'F'],
#        ['DGRP_227', 'M'],
#        ['DGRP_319', 'F'],
#        ['DGRP_319', 'M'],
#        ['DGRP_822', 'F'],
#        ['DGRP_822', 'M'],
#        ['DGRP_189', 'F'],
#        ['DGRP_189', 'M'],
#        ['DGRP_801', 'F'],
#        ['DGRP_801', 'M'],
#        ['DGRP_805', 'F'],
#        ['DGRP_805', 'M'],
#        ['DGRP_892', 'F'],
#        ['DGRP_892', 'M'],
#        ['DGRP_093', 'F'],
#        ['DGRP_093', 'M'],
#        ['DGRP_217', 'F'],
#        ['DGRP_217', 'M'],
#        ['DGRP_391', 'F'],
#        ['DGRP_391', 'M'],
#        ['DGRP_738', 'F'],
#        ['DGRP_738', 'M'],
#        ['DGRP_897', 'F'],
#        ['DGRP_897', 'M'],
#        ['DGRP_318', 'F'],
#        ['DGRP_318', 'M'],
#        ['DGRP_227', 'F'],
#        ['DGRP_227', 'M'],
#        ['DGRP_855', 'F'],
#        ['DGRP_855', 'M'],
#        ['DGRP_627', 'F'],
#        ['DGRP_627', 'M'],
#        ['DGRP_818', 'F'],
#        ['DGRP_818', 'M'],
#        ['DGRP_913', 'F'],
#        ['DGRP_913', 'M']], dtype=object)

# %%
len(unique_dgrp["DGRP"].values
)
# Out:
# 60
